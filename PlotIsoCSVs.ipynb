# %%
import qMS
import pylab
import glob
import pandas
import numpy
import vizLib
import matplotlib.pyplot as plt

# %%
path = '/home/jhdavis/data/2013_07_13-L28DepProcessed/varProcessed/filtered/'
files = glob.glob(path+'*.csv')
files.sort()
num = ['AMP_L']
den = ['AMP_U', 'AMP_S']
offset=0.0
markerSize=12
color='#e31a1c'
yMax = 1.5
files
# Out:
# ['/home/jhdavis/data/2013_07_13-L28DepProcessed/varProcessed/filtered/NCML28_0.2_iso_filt.csv',
#  '/home/jhdavis/data/2013_07_13-L28DepProcessed/varProcessed/filtered/NCML28_0.6_iso_filt.csv',
#  '/home/jhdavis/data/2013_07_13-L28DepProcessed/varProcessed/filtered/NCML28_2_iso_filt.csv',
#  '/home/jhdavis/data/2013_07_13-L28DepProcessed/varProcessed/filtered/NCML28_6_iso_filt.csv']

# %%
scale = 12
defaultFont = {'family' : 'serif',
             'variant' : 'normal',
             'weight' : 400,
             'size' : scale*1}

axisFont = {'titlesize' : scale*1.5,
            'labelsize' : scale*1.25}

axisTitleFont = {'weight' : 700}


xAxisTicks = {'major.size' : 8,
              'minor.size' : 4,
              'major.width' : 1,
              'minor.width' : 1,
              'labelsize' : scale*1,
              'minor.pad' : 1,
              'major.pad' : 1}

yAxisTicks = {'major.size' : 8,
              'minor.size' : 4,
              'major.width' : 1,
              'minor.width' : 1,
              'labelsize' : scale*1,
              'minor.pad' : 3,
              'major.pad' : 3}

legend = {'fancybox' : True,
          'numpoints' : 1,
          'fontsize' : scale*1,
          'borderaxespad' : 1}

matplotlib.rc('font', **defaultFont)
matplotlib.rc('axes', **axisFont)
matplotlib.rc('xtick', **xAxisTicks)
matplotlib.rc('ytick', **yAxisTicks)
matplotlib.rc('legend', **legend)

matplotlib.rc('lines', linewidth=2)
matplotlib.rc('axes', linewidth=3)
##AXISNAME.xaxis.set_ticks_position('bottom')
##AXISNAME.yaxis.set_ticks_position('left')
##AXISNAME.xaxis.labelpad = 2

# %%
a = vizLib.makePlotWithFileList(files, num, den, AllProteins=None, normProtein='L1', yMax=2, colors=['black', '#25557d', '#3170a4', '#5696cc'], 
                                names=['0.2 nM', '0.6 nM', '2.0 nM', '6.0 nM'], figSize=(22,10), median=False)
a.set_xlabel('protein name')
a.set_ylabel('L / [L+U]\nnormalized to L1', multialignment = 'center')
a.legend()
plt.savefig(path+'hslDependenceL28WholeCell.png')
plt.savefig(path+'hslDependenceL28WholeCell.pdf')
