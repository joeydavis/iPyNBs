# %%
import qMS
import pylab
import glob
import pandas
import numpy
import vizLib
import matplotlib.pyplot as plt
import qMSDefs
import os
import clusteringModule

# %% [markdown]
# # Setup enviornment

# %%
vizLib.css_styling()
# Out:
# <style>
#     div.cell{
#         width:150%;
#         margin-left:-30%;
#         margin-right:0%;
#     }
# </style>

# %%
path = '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/'
num = ['AMP_U']
den = ['AMP_S']
files = glob.glob(path+'*_res_filt*_filt.csv')
files = qMS.sort_nicely(files)
names = ['spkAlone', 'curve_2', 'curve_4', 'curve_8', 'curve_16', 'curve_32',
         '1043_45S:RbgAF6A_A', '1051_44SRbgAF6A,L6R70P_A', '1055_44SRbgAF6A,L6R3C_A', '1057_44SRbgAF6A,L6H66L_A', '1068_44SRbgAF6A,L6T68R_A',
         '1043_45S:RbgAF6A_B', '1051_44SRbgAF6A,L6R70P_B', '1055_44SRbgAF6A,L6R3C_B', '1057_44SRbgAF6A,L6H66L_B', '1068_44SRbgAF6A,L6T68R_B',]
#files.append(path+'nj2-1_iso_res_filtAuto.csv')
files
# Out:
# ['/home/jhdavis/data/2014/2014_05_30-NJ2/isos/nj2-1_iso_res_filtHand_filt.csv',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/nj2-2_iso_res_filtAuto_filt.csv',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/nj2-3_iso_res_filtAuto_filt.csv',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/nj2-4_iso_res_filtAuto_filt.csv',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/nj2-5_iso_res_filtAuto_filt.csv',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/nj2-6_iso_res_filtAuto_filt.csv',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/nj2-7_iso_res_filtAuto_filt.csv',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/nj2-8_iso_res_filtAuto_filt.csv',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/nj2-9_iso_res_filtAuto_filt.csv',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/nj2-10_iso_res_filtAuto_filt.csv',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/nj2-11_iso_res_filtAuto_filt.csv',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/nj2-12_iso_res_filtAuto_filt.csv',
# ...

# %%
vizLib.setRcs(scale=16, legendScale=12, axisLineWidth=1)
colors = vizLib.getBCs('q',6)
filePath='/home/jhdavis/Dropbox/WilliamsonLab/Notebooks/ByDate/08/2014_05_30-NJ2_PLOSSubunitsReanalysisFigures/'
savePlots = False
fcounter=0

# %% [markdown]
# # Correct files

# %%
os.system('rm -rf /home/jhdavis/data/2014/2014_05_30-NJ2/isos/corr/')
os.system('mkdir /home/jhdavis/data/2014/2014_05_30-NJ2/isos/corr/')
dictOfDFCurve = qMS.correctListOfFiles(files[0], files[:6], extension='_corrNJ2-1Auto', savePath='/home/jhdavis/data/2014/2014_05_30-NJ2/isos/corr/')
dictOfDFSamples = qMS.correctListOfFiles(files[0], files[6:], extension='_corrNJ2-1Auto', savePath='/home/jhdavis/data/2014/2014_05_30-NJ2/isos/corr/')

# %% [markdown]
# # Plot the raw standard curves

# %%
f = pylab.figure()
subunit = list(qMSDefs.subtilisLargeSubunit)
subunit.remove('BSubL09')
yMax = 2
figSize = [22,8]
median = False
normProtein = None
markerSize=8
highlightMed=True
noFill = False
hms=1.5
alpha=0.25
legend=True
title='raw spectra'
legendCols=6
loc='upper center'
ncol=6

larray = []
for i in range(0,6):
    l = pylab.Line2D(range(1),range(1),color=colors[i],marker='o',markersize=markerSize*hms, markerfacecolor=colors[i],alpha=1.0)
    larray.append(l)

a = vizLib.makePlotWithFileList(files[:6], num, den, subunits=subunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=names[:6], figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N', multialignment = 'center')

a.legend(larray,[names[i] for i in range(0,6)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'stdCurveRawLarge_subs.png', bbox_inches='tight', dpi=300)
    fcounter+=1

f = pylab.figure()
subunit = list(qMSDefs.subtilisSmallSubunit)
subunit.remove('BSubS21')
yMax = 2.0

a = vizLib.makePlotWithFileList(files[:6], num, den, subunits=subunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=names[:6], figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N', multialignment = 'center')

a.legend(larray,[names[i] for i in range(0,6)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'stdCurveRawSmall_subs.png', bbox_inches='tight', dpi=300)
    fcounter+=1

# %% [markdown]
# # Plot corrected standard curve

# %%
path = '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/corr/'
num = ['AMP_U']
den = ['AMP_S']
corFiles = glob.glob(path+'*_res_filt*.csv_*')
corFiles = qMS.sort_nicely(corFiles)
corNames = names
colors = vizLib.getBCs('q',6)
#colors.append('grey')
corFiles
# Out:
# ['/home/jhdavis/data/2014/2014_05_30-NJ2/isos/corr/nj2-1_iso_res_filtHand_filt.csv_corrNJ2-1Auto',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/corr/nj2-2_iso_res_filtAuto_filt.csv_corrNJ2-1Auto',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/corr/nj2-3_iso_res_filtAuto_filt.csv_corrNJ2-1Auto',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/corr/nj2-4_iso_res_filtAuto_filt.csv_corrNJ2-1Auto',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/corr/nj2-5_iso_res_filtAuto_filt.csv_corrNJ2-1Auto',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/corr/nj2-6_iso_res_filtAuto_filt.csv_corrNJ2-1Auto',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/corr/nj2-7_iso_res_filtAuto_filt.csv_corrNJ2-1Auto',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/corr/nj2-8_iso_res_filtAuto_filt.csv_corrNJ2-1Auto',
#  '/home/jhdavis/data/2014/2014_05_30-NJ2/isos/corr/nj2-9_iso_res_filtAuto_filt.csv_corrNJ2-1Auto',
# ...

# %%
f = pylab.figure()
largeSubunit = list(qMSDefs.subtilisLargeSubunit)
largeSubunit.remove('BSubL09')
yMax = 1.5
figSize = [22,8]
median = False
normProtein = None
markerSize=8
highlightMed=True
noFill = False
hms=1.5
alpha=0.25
legend=True
title='corected spectra'
legendCols=6
#colors=colors[1:]


larray = []
for i in range(0,5):
    l = pylab.Line2D(range(1),range(1),color=colors[i],marker='o',markersize=markerSize*hms, markerfacecolor=colors[i],alpha=1.0)
    larray.append(l)


a = vizLib.makePlotWithFileList(corFiles[:6], num, den, subunits=largeSubunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=corNames[:6], figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N cor [norm L20]', multialignment = 'center')
a.legend(larray,[corNames[i] for i in range(0,5)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'stdCurveCorrLarge_subs.png', bbox_inches='tight', dpi=300)
    fcounter+=1

f = pylab.figure()
smallSubunit = list(qMSDefs.subtilisSmallSubunit)
smallSubunit.remove('BSubS21')
yMax = 1.5

a = vizLib.makePlotWithFileList(corFiles[:6], num, den, subunits=smallSubunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=corNames[:6], figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N cor [norm L20]', multialignment = 'center')

a.legend(larray,[corNames[i] for i in range(0,5)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'stdCurveCorrSmall_subs.png', bbox_inches='tight', dpi=300)
    fcounter+=1

# %% [markdown]
# # Make stadard curve scatter plot

# %%
values = numpy.array([0, 2, 4, 8, 15, 32])

# %%
stdCurveCorrectedStats = qMS.multiStatsDictFromDF(dictOfDFCurve, num, den, namesList=None, normalization=1.0, offset=0.0, normProtein=None)

# %%
smallSubunitList = qMS.calculateMedian(stdCurveCorrectedStats, files[:6], smallSubunit)
largeSubunitList = qMS.calculateMedian(stdCurveCorrectedStats, files[:6], largeSubunit)
allSubunitList = qMS.calculateMedian(stdCurveCorrectedStats, files[:6], largeSubunit+smallSubunit)

# %%
yLabel = 'N14/N15 [corrected]'
sc = vizLib.proteinScatterPlot(smallSubunitList, values, xMin=-1, xMax=33, yMin=-0.05, yMax=1.2,
                       title='Small subunit\nstandard curve [corrected]', xLabel='pmol 14N', yLabel=yLabel, colors=None, alpha=1,
                       figSize=(10,10), markerSize=10, legend=True, linestyle='--', xTicks=[0, 2, 4, 8, 16, 32])
if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'stdCurveScatterSmall.png', bbox_inches='tight', dpi=300)
    fcounter+=1

# %%
yLabel = 'N14/N15 [corrected]'
sc = vizLib.proteinScatterPlot(largeSubunitList, values, xMin=-1, xMax=33, yMin=-0.05, yMax=1.2,
                       title='Large subunit\nstandard curve [corrected]', xLabel='pmol 14N', yLabel=yLabel, colors=None, alpha=1,
                       figSize=(10,10), markerSize=10, legend=True, linestyle='--', xTicks=[0, 2, 4, 8, 16, 32])
if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'stdCurveScatterLarge.png', bbox_inches='tight', dpi=300)
    fcounter+=1

# %%
yLabel = 'N14/N15 [corrected]'
sc = vizLib.proteinScatterPlot(allSubunitList, values, xMin=-1, xMax=33, yMin=-0.05, yMax=1.2,
                       title='All subunit\nstandard curve [corrected]', xLabel='pmol 14N', yLabel=yLabel, colors=None, alpha=1,
                       figSize=(10,10), markerSize=10, legend=False, linestyle='--', xTicks=[0, 2, 4, 8, 16, 32])
if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'stdCurveScatterAll.png', bbox_inches='tight', dpi=300)
    fcounter+=1

# %% [markdown]
# # Plot the actual data [uncorrected]

# %%
colors = vizLib.getBCs('p', 10)
pairedOrder = [6, 11, 7, 12, 8, 13, 9, 14, 10, 15, 4, 5]
pairedFiles = [files[i] for i in pairedOrder]
pairedNames = [names[i] for i in pairedOrder]
colors.append('grey')
colors.append('black')

# %%
f = pylab.figure()
subunit = list(qMSDefs.subtilisLargeSubunit)
subunit.remove('BSubL09')
yMax = 3
figSize = [22,8]
median = False
normProtein = None
markerSize=5
highlightMed=True
noFill = False
hms=2
alpha=1
legend=True
title='raw spectra'
legendCols=5
loc='upper center'
ncol=6
mew=0.1

num = ['AMP_U']
den = ['AMP_S']

larray = []
totalFiles = 12
for i in range(0,totalFiles):
    l = pylab.Line2D(range(1),range(1),color=colors[i],marker='o',markersize=markerSize*hms, markerfacecolor=colors[i],alpha=1.0)
    larray.append(l)

a = vizLib.makePlotWithFileList(pairedFiles, num, den, subunits=subunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=pairedNames, figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols, mew = mew)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N', multialignment = 'center')

a.legend(larray,[pairedNames[i] for i in range(0,totalFiles)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'subunitsRawLarge.png', bbox_inches='tight', dpi=300)
    fcounter+=1

f = pylab.figure()
subunit = list(qMSDefs.subtilisSmallSubunit)
subunit.remove('BSubS21')
yMax = 3.0

a = vizLib.makePlotWithFileList(pairedFiles, num, den, subunits=subunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=pairedNames, figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols, mew=mew)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N', multialignment = 'center')

a.legend(larray,[pairedNames[i] for i in range(0,totalFiles)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'subunitsRawSmall.png', bbox_inches='tight', dpi=300)
    fcounter+=1

# %% [markdown]
# # Plot the actual data [corrected]

# %%
colors = vizLib.getBCs('p', 10)
pairedOrder = [6, 11, 7, 12, 8, 13, 9, 14, 10, 15, 4, 5]
pairedFiles = [corFiles[i] for i in pairedOrder]
pairedNames = [names[i] for i in pairedOrder]
colors.append('grey')
colors.append('black')

# %%
f = pylab.figure()
subunit = list(qMSDefs.subtilisLargeSubunit)
subunit.remove('BSubL09')
yMax = 1.8
figSize = [30,8]
median = False
normProtein = 'BSubL20'
markerSize=5
highlightMed=True
noFill = False
hms=2
alpha=1
legend=True
title='corrected spectra'
legendCols=6
loc='upper center'
ncol=6
mew=0.1

num = ['AMP_U']
den = ['AMP_S']

larray = []
totalFiles = 12
for i in range(0,totalFiles):
    l = pylab.Line2D(range(1),range(1),color=colors[i],marker='o',markersize=markerSize*hms, markerfacecolor=colors[i],alpha=1.0)
    larray.append(l)

a = vizLib.makePlotWithFileList(pairedFiles, num, den, subunits=subunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=pairedNames, figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols, mew = mew)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N', multialignment = 'center')

a.legend(larray,[pairedNames[i] for i in range(0,totalFiles)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'subunitsCorrLarge.png', bbox_inches='tight', dpi=300)
    fcounter+=1

f = pylab.figure()
subunit = list(qMSDefs.subtilisSmallSubunit)
subunit.remove('BSubS21')
yMax = 1.8

a = vizLib.makePlotWithFileList(pairedFiles, num, den, subunits=subunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=pairedNames, figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols, mew=mew)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N', multialignment = 'center')

a.legend(larray,[pairedNames[i] for i in range(0,totalFiles)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'subunitsCorrSmall.png', bbox_inches='tight', dpi=300)
    fcounter+=1

# %% [markdown]
# # Generate heatmaps using the median values

# %%
nameDict = {files[i] : names[i][:7] for i in range(0,16)}

# %%
curve = qMS.outputDataMatrixFile(path+'curveHeatData', dictOfDFCurve, files[:6], num, den, subunits=largeSubunit+smallSubunit, 
                         normalization=1.0, offset=0, normProtein=None, rowNorms=None, delimiter='\t', )

# %%
curve = qMS.readDataFile(path+'curveHeatData', scale=1.0, delimiter='\t')

# %%
a = vizLib.drawHeatMap(curve, name='stdCurve', dendro=False, colorBar=True, figSize=(10,5), topDendro=False, nameDict = nameDict)

# %%
subs = qMS.outputDataMatrixFile(path+'subHeatData', dictOfDFSamples, files[6:], num, den, subunits=largeSubunit, 
                         normalization=1.0, offset=0, normProtein='BSubL20', rowNorms=None, delimiter='\t')

# %%
subs = qMS.readDataFile(path+'test.txt', scale=1.0, delimiter=',')

# %%
subsClus = clusteringModule.clusterData(subs, columnMethod=True, rowMethod=True)

# %%
subsClus['rightDendro']
# Out:
# array([[ 0.        ,  2.        ,  0.03925497,  2.        ],
#        [ 1.        ,  3.        ,  0.18077612,  3.        ]])

# %%
import scipy.cluster.hierarchy as sch

def drawHeatMap(xdat, name=None, colors=pylab.cm.Reds, dendro=False, protColors=None, cIndex=None, km=None, mine=False,
                nameDict={}, scale=None, saveName=None, colorBar=False, figSize=(6,6), topDendro=False, fig=None, axData=None):
    """drawHeatMap produces a colored heatmap in a new figure window

    :param xdat: a data object (must contain fields 'data', 'fractions', 'proteins')
    :type xdat: dict
    :param colors: a color scale (a cmap)
    :type colors: cmap
    :param name: figure name and title
    :type name: str.
    :param dendro: a boolean to draw the dendrogram on the left
    :type dendro: bool.
    :param protColors: a color map used to label the protein names with group colors
    :type protColors: cmap
    :param cIndex: a list of groupIds for the proteins
    :type cIndex: list
    :param km: if present, will draw the kmeans cluster profiles at the top of the figure- input is a 2d-matrix - rowVectors for each centroid, each column is a fraction
    :type km: matrix
    :returns:  int -- the return code.
    :raises: AttributeError, KeyError
    :returns: a figure object

    """

    data = xdat['data']
    if nameDict is None:
        nameList = [i for i in xdat['fractions']]
    else:
        nameList = [nameDict[i] for i in xdat['fractions']]

    proteins = [i for i in xdat['proteins']]
    if fig is None:
        fig = pylab.figure(figsize=figSize)
    if not (name is None):
        fig.suptitle(name)
    ##Draw heatmap
    xOffset = 0.05
    if colorBar:
        xLess = 0.10
    else:
        xLess = 0.00
    if dendro:
        xStart = 0.375
        xLength = 0.55-xLess
    else:
        xStart = 0.125
        xLength = 0.85-xLess
    if (km is None) and (topDendro is False):
        yStart = 0.05
        yLength = 0.9
    else:
        yStart = 0.05
        yLength = 0.8
    figAxes = vizLib.heatMapAxes(data, dims = [xStart, yStart, xLength, yLength], columns=nameList, rows=proteins, protColors=protColors, cIndex=cIndex, fig=fig, colors=colors, axData=axData)
    ##Draw colorbar
    if colorBar:
        fig.colorbar(figAxes)

    if dendro:
        ax2Data = fig.add_axes([xOffset, yStart, xLength-0.3, yLength])
        hold = xdat['rightDendro']
        print hold
        #order = [1,0]
        #hold = numpy.array([hold[i] for i in order])
        #print hold
        dData = sch.dendrogram(hold, orientation='right', color_threshold=0.0, no_plot=True)

        if mine:
            ax2Data = drawDendrogram(dData, ax2Data)
        else:
            sch.dendrogram(hold, orientation='right', color_threshold=0.0, no_plot=False, distance_sort='ascending')
        ax2Data.set_xticks([])
        ax2Data.set_yticks([])
    
    if topDendro:
        ax4Data = fig.add_axes([xStart, yStart+yLength, xLength, 0.1])
        sch.dendrogram(xdat['topDendro'], orientation='down', color_threshold=0.0)
        ax4Data.set_xticks([])
        ax4Data.set_yticks([])
    
    if not km is None:
        small = data.min()
        big = data.max()
        if math.fabs(small) > math.fabs(big):
            big = 0-small
        else:
            small = 0-big
        offset=0.0
        ax3Data = fig.add_axes([xStart, yLength+offset, xLength-0.1, 0.1])
        ax3Data.matshow(km, aspect='auto', origin='lower', cmap=colors, vmin=small, vmax=big)
        for i in range(len(km)):
            ax3Data.text(-0.75, i, 'clus'+str(i), verticalalignment="center", horizontalalignment="right", fontsize=10, color=cIndex(float(i)/(protColors.max()+1)))
        ax3Data.set_xticks([])
        ax3Data.set_yticks([])
    #fig.tight_layout()
    if not (saveName is None):
        pylab.savefig(saveName)
        
    return fig

# %%
def drawDendrogram(ddata, axis, pos=False):
    icoord = numpy.array( ddata['icoord'] )
    dcoord = numpy.array( ddata['dcoord'] )
    color_list = numpy.array( ddata['color_list'] )
    xmin, xmax = icoord.min(), icoord.max()
    ymin, ymax = dcoord.min(), dcoord.max()
    if pos:
        icoord = icoord[pos]
        dcoord = dcoord[pos]
        color_list = color_list[pos]
    for xs, ys, color in zip(icoord, dcoord, color_list):
        axis.plot(xs, ys,  color)
    axis.set_xlim( xmin-10, xmax + 0.1*abs(xmax) )
    axis.set_ylim( ymin, ymax + 0.1*abs(ymax) )
    #return axis

# %%
a = drawHeatMap(subsClus, name='subunits', dendro=True, mine = False, colorBar=False, figSize=(20,5), topDendro=False, nameDict = nameDict)
# Out:
# [[ 0.          2.          0.03925497  2.        ]
#  [ 1.          3.          0.18077612  3.        ]]

# %%
a = drawHeatMap(subsClus, name='subunits', dendro=True, mine = False, colorBar=False, figSize=(20,5), topDendro=False, nameDict = nameDict)
