# %%
import qMS
import pandas
import vizLib
import pylab

# %%
fp = '/home/jhdavis/data/2013_03_11-NCMGradients/SingleSpike/isos/S20_peaks/'
fn = 'S9_33_40_0_999.48996988013_64.678465.plots'
plotsfile = fp+fn
tfn = 'S9_33_40_0_999.48996988013_64.678465.txt'
txtfile = fp+tfn

# %%
df = pandas.read_csv(plotsfile)
df2 = pandas.read_csv(txtfile, header=None, sep=' ')

# %%
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 577 entries, 0 to 576
# Data columns:
# 0    577  non-null values
# 1    577  non-null values
# dtypes: float64(2)

# %%
del df['residAdj']

# %%
#df.plot(figsize=(12,10), style=['x', '-', '-'])
f = pylab.figure(figsize=(12,10))
ax = f.add_subplot(111)
ax.plot(df2[0][0:len(df['dat'])].values, df['dat'].values, 'ro', markersize=8, label='data', markerfacecolor='None', markeredgecolor='red')
ax.plot(df2[0][0:len(df['fit'])].values, df['fit'].values, 'b-', linewidth=2, label='fit')
ax.plot(df2[0][0:len(df['resid'])].values, df['resid'].values, 'g-', linewidth=2, label='residual')
ax.set_xlabel('m/z', size=20)
ax.set_ylabel('intensity', size=20)
ax.legend(prop={'size':20})
pylab.title(fn, size=25)
#df.plot(x=df2[0][0:len(df['fit'])], y=df['fit'], figsize=(12,10), style=['x', '-', '-'])

# %%
df2.plot()

# %%
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 405 entries, 0 to 404
# Data columns:
# 0    405  non-null values
# 1    405  non-null values
# dtypes: float64(2)

# %%
df2[0].max()
# Out:
# 624.59941500000002
