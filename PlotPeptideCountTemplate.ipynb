# %%
import qMS
import pylab
import glob
import pandas
import numpy
import vizLib
import matplotlib.pyplot as plt
import qMSDefs

# %%
path = '/home/jhdavis/dec2013Processing/2013_12_19-JSIVS10/'
num = ['AMP_U']
den = ['AMP_S']
files = glob.glob(path+'*_res.csv')
files.sort()
names = ['Exp_alone', 'Exp+14N+15N', 'Exp+14N', 'Exp+15N', '14N+15N']

# %%
vizLib.setRcs(scale=16, legendScale=16)
files
colors = vizLib.getBCs('q',5)
filePath='/home/jhdavis/Dropbox/WilliamsonLab/Notebooks/ByDate/06-2013_08_01 -/2014_01_07-FiguresForJSInVitroS10OldBadData/'

# %%
ps = qMSDefs.positionLabelsSpc
a = vizLib.plotPeptideCount(files, labels=names, colors=colors, proteins=ps, figSize=(18,6))
a.set_xlim([0,11])
pylab.savefig(filePath+'SpcCounts.png', bbox_inches='tight')
