# %%
import numpyimport scipyfrom scipy import statsimport pylabimport csvimport os

# %%
path = '/home/jhdavis/Dropbox/fromLinux'files = [f for f in os.listdir(path)]readFiles = {}rowNames = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']colNames = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']allDat = {}for i in rowNames:    for j in colNames:        allDat[i+j] = []timePoints = [0, 47, 88, 134, 157, 260]for f in files:    fil = path+'/'+f    readFiles[fil]=[]    reader = csv.reader(open(fil, "rb"), delimiter='\t')    for row, record in enumerate(reader):        readFiles[fil].append(record)ks = readFiles.keys()ks.sort()for k in ks:    for r, row in enumerate(readFiles[k]):        for c, col in enumerate(row):            allDat[rowNames[r]+colNames[c]].append(col)ks = allDat.keys()ks.sort()f = pylab.figure()ax = f.add_subplot(111)slope = {}yVals = {}for k in ks:    yVals[k] = [numpy.log2(float(x)) for x in allDat[k]]    s = float(stats.linregress(timePoints,yVals[k])[0])    slope[k] = svalues = [float(x) for x in slope.values()]ax.bar(range(96), values, 1)ax.set_xticks(range(96))ax.set_xticklabels( ks )
# Out:
# [<matplotlib.text.Text at 0x3517350>, <matplotlib.text.Text at 0x351b710>, <matplotlib.text.Text at 0x3513dd0>, <matplotlib.text.Text at 0x3522410>, <matplotlib.text.Text at 0x3522a50>, <matplotlib.text.Text at 0x3524110>, <matplotlib.text.Text at 0x37b6e10>, <matplotlib.text.Text at 0x37b94d0>, <matplotlib.text.Text at 0x37b9b50>, <matplotlib.text.Text at 0x37bc210>, <matplotlib.text.Text at 0x37bc890>, <matplotlib.text.Text at 0x37bcf10>, <matplotlib.text.Text at 0x37c05d0>, <matplotlib.text.Text at 0x37c0c50>, <matplotlib.text.Text at 0x37c1310>, <matplotlib.text.Text at 0x37c1990>, <matplotlib.text.Text at 0x37c5050>, <matplotlib.text.Text at 0x37c56d0>, <matplotlib.text.Text at 0x37c5d50>, <matplotlib.text.Text at 0x37c8410>, <matplotlib.text.Text at 0x37c8a90>, <matplotlib.text.Text at 0x37cb150>, <matplotlib.text.Text at 0x37cb7d0>, <matplotlib.text.Text at 0x37cbe50>, <matplotlib.text.Text at 0x37cf510>, <matplotlib.text.Text at 0x37cfb90>, <matplotlib.text.Text at 0x37d2250>
# ...
