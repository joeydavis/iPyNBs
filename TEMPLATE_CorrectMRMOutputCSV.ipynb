# %%
import mrmTools
import qMS
import pandas
import numpy
import scipy
import matplotlib
import pylab
import vizLib
import glob
import qMSDefs

# %%
vizLib.setRcs(axisLineWidth=1)

# %%
path = '/home/jhdavis/Dropbox/fromLinux/'

# %%
set1Path = glob.glob(path+'*.csv')[3]

# %%
set1 = mrmTools.readMRMCSV(set1Path)

# %%
set1['currentCalc'] = mrmTools.calcValue(set1, ['heavy '], ['light '])

# %%
allFiles = mrmTools.makeFileStatsDictMRM(set1)

# %%
files = list(set1['File Name'].unique())
files = qMS.sort_nicely(files)
fd = [[i,i.split('.')[0]] for i in files]

# %%
vizLib.makePlotWithStatsDictDict(allFiles, namesList = fd, subunits = qMSDefs.positionLabels50S, legend=True, yMax=5)

# %%
a = qMS.outputDataMatrixFileFromSDD('/home/jhdavis/Dropbox/fromLinux/set1CSVTest.csv', allFiles, files)
# Out:
# /usr/lib/python2.7/dist-packages/numpy/core/_methods.py:55: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
