# %%
import qMS
import pylab
import glob
import pandas
import numpy
import vizLib
import matplotlib.pyplot as plt

# %%
scale = 12
defaultFont = {'family' : 'serif',
             'variant' : 'normal',
             'weight' : 400,
             'size' : scale*1}

axisFont = {'titlesize' : scale*1.5,
            'labelsize' : scale*1.25}

axisTitleFont = {'weight' : 700}


xAxisTicks = {'major.size' : 8,
              'minor.size' : 4,
              'major.width' : 1,
              'minor.width' : 1,
              'labelsize' : scale*1,
              'minor.pad' : 3,
              'major.pad' : 3}

yAxisTicks = {'major.size' : 8,
              'minor.size' : 4,
              'major.width' : 1,
              'minor.width' : 1,
              'labelsize' : scale*1,
              'minor.pad' : 3,
              'major.pad' : 3}

legend = {'fancybox' : True,
          'numpoints' : 1,
          'fontsize' : scale*1,
          'borderaxespad' : 1}

matplotlib.rc('font', **defaultFont)
matplotlib.rc('axes', **axisFont)
matplotlib.rc('xtick', **xAxisTicks)
matplotlib.rc('ytick', **yAxisTicks)
matplotlib.rc('legend', **legend)

matplotlib.rc('lines', linewidth=2)
matplotlib.rc('axes', linewidth=3)
##AXISNAME.xaxis.set_ticks_position('bottom')
##AXISNAME.yaxis.set_ticks_position('left')
##AXISNAME.xaxis.labelpad = 2

# %%
path = '/home/jhdavis/data/JStokes/2013_10_14-JStokesWholeCell2ESI/'
f1 = '1reinjec_iso.csv'
f2 = '2_iso.csv'
f3 = '3_iso.csv'
f4 = '4_iso.csv'
f5 = '5_iso.csv'
f6 = '6_iso.csv'

files = [path + i for i in [f1, f2, f3, f4, f5, f6]]
    
labels = ['1 : Lam 1 hr', '2 : DMSO 1 hr', '3 : Cm 1 hr', '4 : Lam 6 hr', '5 : DMSO 6 hr', '6 : Cm 6 hr']

files1 = files[0:3]
labels1 = labels[0:3]

files6 = files[3:]
labels6 = labels[3:]

num = ['AMP_U']
den = ['AMP_S']
cmList = [1,4,2,5]

# %%
a = vizLib.makePlotWithFileList([files[i] for i in cmList], num, den, yMax=1.20, colors=None, 
                                names=[labels[i] for i in cmList], figSize=(33,8), median=False, normProtein='L5')
a.set_xlabel('protein name')
a.set_ylabel('U / [S+U]', multialignment = 'center')
#a.set_xlim([1,31])
a.legend(loc='upper left', ncol=4)
#a.set_title('45S labeling')
#plt.savefig('/home/jhdavis/45S.png')

# %%
lamList = [1,4,0,3]
a = vizLib.makePlotWithFileList([files[i] for i in lamList], num, den, yMax=1.20, colors=None, 
                                names=[labels[i] for i in lamList], figSize=(33,8), median=True, normProtein='L5')
a.set_xlabel('protein name')
a.set_ylabel('U / [S+U]', multialignment = 'center')
#a.set_xlim([1,31])
a.legend(loc='upper left', ncol=4)
#a.set_title('45S labeling')
#plt.savefig('/home/jhdavis/45S.png')

# %%
allList = [1,4,0,3,2,5]
a = vizLib.makePlotWithFileList([files[i] for i in allList], num, den, yMax=1.20, colors=None, 
                                names=[labels[i] for i in allList], figSize=(33,8), median=True, normProtein='L5')
a.set_xlabel('protein name')
a.set_ylabel('U / [S+U]', multialignment = 'center')
#a.set_xlim([1,31])
a.legend(loc='upper left', ncol=6)
#a.set_title('45S labeling')
#plt.savefig('/home/jhdavis/45S.png')
