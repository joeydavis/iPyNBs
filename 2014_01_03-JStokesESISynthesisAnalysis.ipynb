# %%
import qMS
import pylab
import glob
import pandas
import numpy
import vizLib
import matplotlib.pyplot as plt
import qMSDefs
import scipy

# %%
vizLib.setRcs(scale=14, legendScale=14)

# %%
path = '/home/jhdavis/dec2013Processing/2013_12_12-JSIVPESIOffset/filteredIsos/'

# %%
files = qMS.sort_nicely([i for i in glob.glob(path+'*.csv')])
labels = ['0:00', '2:40', '4:00', '8:00', '16:00']
DMSO = files[0:5]
CAM = files[5:10]
LAM = files[10:15]
ERM = files[15:20]
smallSubunit = qMSDefs.positionLabels30S[1:]
largeSubunit = qMSDefs.positionLabels50S[1:]
allSubunit = qMSDefs.positionLabels70S[1:]
allSubunit.remove('L12')
allSubunit.remove('S22')
allSubunit.remove('L8')
allSubunit.remove('L26')

# %%
num = ['AMP_U', 'AMP_L']
den = ['AMP_U', 'AMP_L', 'AMP_S']
savePath = '/home/jhdavis/Dropbox/WilliamsonLab/Notebooks/ByDate/06-2013_08_01 -/2014_01_02-JStokesInVivoSynthesisESIFigures/'
baseName = 'protein levels_All'
baseAxis = '[14N + 50%15N] / [14N + 50%15N + 15N]'
yMax = 0.75
normProtein=None
s = allSubunit

colors = vizLib.getBCs('s', 5, name='Blues')
a = vizLib.makePlotWithFileList(DMSO, num, den, colors=colors, yMax = yMax, normProtein=normProtein,
                                names=labels, figSize=(22,8.5), median=False, subunits=s, highlightMed=True, markerSize=5)
a.legend(loc='upper left', ncol=5)
a.set_title(baseName+' DMSO')
a.set_ylabel(baseAxis, multialignment = 'center')
vizLib.cleanAxis(a,ticksOnly=True)
pylab.tight_layout()
#pylab.savefig(savePath+'DMSO_'+baseName+'.png')
#pylab.savefig(savePath+'DMSO_'+baseName+'.pdf')


colors = vizLib.getBCs('s', 5, name='Reds')
a = vizLib.makePlotWithFileList(CAM, num, den, colors=colors, yMax = yMax, normProtein=normProtein,
                                names=labels, figSize=(22,8.5), median=False, subunits=s, highlightMed=True, markerSize=5)
a.legend(loc='upper left', ncol=5)
a.set_title(baseName+' CAM')
a.set_ylabel(baseAxis, multialignment = 'center')
vizLib.cleanAxis(a,ticksOnly=True)
pylab.tight_layout()
#pylab.savefig(savePath+'CAM_'+baseName+'.png')
#pylab.savefig(savePath+'CAM_'+baseName+'.pdf')


colors = vizLib.getBCs('s', 5, name='Greens')
a = vizLib.makePlotWithFileList(LAM, num, den, colors=colors, yMax = yMax, normProtein=normProtein,
                                names=labels, figSize=(22,8.5), median=False, subunits=s, highlightMed=True, markerSize=5)
a.legend(loc='upper left', ncol=5)
a.set_title(baseName+' LAM')
a.set_ylabel(baseAxis, multialignment = 'center')
vizLib.cleanAxis(a,ticksOnly=True)
pylab.tight_layout()
#pylab.savefig(savePath+'LAM_'+baseName+'.png')
#pylab.savefig(savePath+'LAM_'+baseName+'.pdf')


colors = vizLib.getBCs('s', 5, name='Purples')
a = vizLib.makePlotWithFileList(ERM, num, den, colors=colors, yMax = yMax, normProtein=normProtein,
                                names=labels, figSize=(22,8.5), median=False, subunits=s, highlightMed=True, markerSize=5)
a.legend(loc='upper left', ncol=5)
a.set_title(baseName+' ERM')
a.set_ylabel(baseAxis, multialignment = 'center')
vizLib.cleanAxis(a,ticksOnly=True)
pylab.tight_layout()
#pylab.savefig(savePath+'ERM_'+baseName+'.png')
#pylab.savefig(savePath+'ERM_'+baseName+'.pdf')

# %%
num = ['AMP_U']
den = ['AMP_U','AMP_S']
savePath = '/home/jhdavis/Dropbox/WilliamsonLab/Notebooks/ByDate/06-2013_08_01 -/2014_01_02-JStokesInVivoSynthesisESIFigures/'
baseName = 'degradation_All'
baseAxis = '[14N] / [14N + 15N]'
yMax = 0.5
normProtein=None

colors = vizLib.getBCs('s', 5, name='Blues')
a = vizLib.makePlotWithFileList(DMSO, num, den, colors=colors, yMax = yMax, normProtein=normProtein,
                                names=labels, figSize=(22,8.5), median=False, subunits=s, highlightMed=True, markerSize=5)
a.legend(loc='upper left', ncol=5)
a.set_title(baseName+' DMSO')
a.set_ylabel(baseAxis, multialignment = 'center')
vizLib.cleanAxis(a,ticksOnly=True)
pylab.tight_layout()
#pylab.savefig(savePath+'DMSO_'+baseName+'.png')
#pylab.savefig(savePath+'DMSO_'+baseName+'.pdf')


colors = vizLib.getBCs('s', 5, name='Reds')
a = vizLib.makePlotWithFileList(CAM, num, den, colors=colors, yMax = yMax, normProtein=normProtein,
                                names=labels, figSize=(22,8.5), median=False, subunits=s, highlightMed=True, markerSize=5)
a.legend(loc='upper left', ncol=5)
a.set_title(baseName+' CAM')
a.set_ylabel(baseAxis, multialignment = 'center')
vizLib.cleanAxis(a,ticksOnly=True)
pylab.tight_layout()
#pylab.savefig(savePath+'CAM_'+baseName+'.png')
#pylab.savefig(savePath+'CAM_'+baseName+'.pdf')


colors = vizLib.getBCs('s', 5, name='Greens')
a = vizLib.makePlotWithFileList(LAM, num, den, colors=colors, yMax = yMax, normProtein=normProtein,
                                names=labels, figSize=(22,8.5), median=False, subunits=s, highlightMed=True, markerSize=5)
a.legend(loc='upper left', ncol=5)
a.set_title(baseName+' LAM')
a.set_ylabel(baseAxis, multialignment = 'center')
vizLib.cleanAxis(a,ticksOnly=True)
pylab.tight_layout()
#pylab.savefig(savePath+'LAM_'+baseName+'.png')
#pylab.savefig(savePath+'LAM_'+baseName+'.pdf')


colors = vizLib.getBCs('s', 5, name='Purples')
a = vizLib.makePlotWithFileList(ERM, num, den, colors=colors, yMax = yMax, normProtein=normProtein,
                                names=labels, figSize=(22,8.5), median=False, subunits=s, highlightMed=True, markerSize=5)
a.legend(loc='upper left', ncol=5)
a.set_title(baseName+' ERM')
a.set_ylabel(baseAxis, multialignment = 'center')
vizLib.cleanAxis(a,ticksOnly=True)
pylab.tight_layout()
#pylab.savefig(savePath+'ERM_'+baseName+'.png')
#pylab.savefig(savePath+'ERM_'+baseName+'.pdf')

# %%
num = ['AMP_L']
den = ['AMP_L','AMP_S']
savePath = '/home/jhdavis/Dropbox/WilliamsonLab/Notebooks/ByDate/06-2013_08_01 -/2014_01_02-JStokesInVivoSynthesisESIFigures/'
baseName = 'synthesis_All'
baseAxis = '[50%15N] / [50%15N + 15N]'
yMax = 0.6
normProtein=None

colors = vizLib.getBCs('s', 5, name='Blues')
a = vizLib.makePlotWithFileList(DMSO, num, den, colors=colors, yMax = yMax, normProtein=normProtein,
                                names=labels, figSize=(22,8.5), median=False, subunits=s, highlightMed=True, markerSize=5)
a.legend(loc='upper left', ncol=5)
a.set_title(baseName+' DMSO')
a.set_ylabel(baseAxis, multialignment = 'center')
vizLib.cleanAxis(a,ticksOnly=True)
pylab.tight_layout()
#pylab.savefig(savePath+'DMSO_'+baseName+'.png')
#pylab.savefig(savePath+'DMSO_'+baseName+'.pdf')


colors = vizLib.getBCs('s', 5, name='Reds')
a = vizLib.makePlotWithFileList(CAM, num, den, colors=colors, yMax = yMax, normProtein=normProtein,
                                names=labels, figSize=(22,8.5), median=False, subunits=s, highlightMed=True, markerSize=5)
a.legend(loc='upper left', ncol=5)
a.set_title(baseName+' CAM')
a.set_ylabel(baseAxis, multialignment = 'center')
vizLib.cleanAxis(a,ticksOnly=True)
pylab.tight_layout()
#pylab.savefig(savePath+'CAM_'+baseName+'.png')
#pylab.savefig(savePath+'CAM_'+baseName+'.pdf')


colors = vizLib.getBCs('s', 5, name='Greens')
a = vizLib.makePlotWithFileList(LAM, num, den, colors=colors, yMax = yMax, normProtein=normProtein,
                                names=labels, figSize=(22,8.5), median=False, subunits=s, highlightMed=True, markerSize=5)
a.legend(loc='upper left', ncol=5)
a.set_title(baseName+' LAM')
a.set_ylabel(baseAxis, multialignment = 'center')
vizLib.cleanAxis(a,ticksOnly=True)
pylab.tight_layout()
#pylab.savefig(savePath+'LAM_'+baseName+'.png')
#pylab.savefig(savePath+'LAM_'+baseName+'.pdf')


colors = vizLib.getBCs('s', 5, name='Purples')
a = vizLib.makePlotWithFileList(ERM, num, den, colors=colors, yMax = yMax, normProtein=normProtein,
                                names=labels, figSize=(22,8.5), median=False, subunits=s, highlightMed=True, markerSize=5)
a.legend(loc='upper left', ncol=5)
a.set_title(baseName+' ERM')
a.set_ylabel(baseAxis, multialignment = 'center')
vizLib.cleanAxis(a,ticksOnly=True)
pylab.tight_layout()
#pylab.savefig(savePath+'ERM_'+baseName+'.png')
#pylab.savefig(savePath+'ERM_'+baseName+'.pdf')

# %%
num = ['AMP_L']
den = ['AMP_S']

msdDMSO = qMS.multiStatsDict(DMSO, num, den, normalization=1.0, offset=0.0, normProtein=None)
msdCAM = qMS.multiStatsDict(CAM, num, den, normalization=1.0, offset=0.0, normProtein=None)
msdLAM = qMS.multiStatsDict(LAM, num, den, normalization=1.0, offset=0.0, normProtein=None)
msdERM = qMS.multiStatsDict(ERM, num, den, normalization=1.0, offset=0.0, normProtein=None)

allListDMSO = qMS.calculateMedian(msdDMSO, DMSO, allSubunit)
allListCAM = qMS.calculateMedian(msdCAM, CAM, allSubunit)
allListLAM = qMS.calculateMedian(msdLAM, LAM, allSubunit)
allListERM = qMS.calculateMedian(msdERM, ERM, allSubunit)

# %%
time = [0, 160, 240, 480, 960]

# %%
f = pylab.figure(figsize=(15,20))
a = f.add_subplot(221)
b = f.add_subplot(222)
c = f.add_subplot(223)
d = f.add_subplot(224)
yMax=1

a = vizLib.proteinScatterPlot(allListDMSO, time, xMin = -5, xMax = 995, yMin = 0, yMax = yMax, title='DMSO', xLabel = 'time (mins)', yLabel = '50%15N/[15N]', figSize = (5.5,8), markerSize=100, linestyle='-', axes=a)
a.legend(loc='upper left', ncol=4, scatterpoints=1)
b = vizLib.proteinScatterPlot(allListCAM, time, xMin = -5, xMax = 995, yMin = 0, yMax = yMax, title='CAM', xLabel = 'time (mins)', yLabel = '50%15N/[15N]', figSize = (5.5,8), markerSize=100, linestyle='-', axes=b)
c = vizLib.proteinScatterPlot(allListLAM, time, xMin = -5, xMax = 995, yMin = 0, yMax = yMax, title='LAM', xLabel = 'time (mins)', yLabel = '50%15N/[15N]', figSize = (5.5,8), markerSize=100, linestyle='-', axes=c)
d = vizLib.proteinScatterPlot(allListERM, time, xMin = -5, xMax = 995, yMin = 0, yMax = yMax, title='ERM', xLabel = 'time (mins)', yLabel = '50%15N/[15N]', figSize = (5.5,8), markerSize=100, linestyle='-', axes=d)
pylab.savefig(savePath+'SynthesisPlots.png')
pylab.savefig(savePath+'SynthesisPlots.pdf')

# %%
def getSlopes(l, t=[240, 480, 960]):
    slopeDict = {}
    for p in l.keys():
        v = l[p][2:]
        slopeDict[p] = max(numpy.polyfit(t, v, 1)[0],0.0)
    return slopeDict

# %%
Blue = vizLib.getBCs('s', 5, name='Blues')[-2]
Red = vizLib.getBCs('s', 5, name='Reds')[-2]
Green = vizLib.getBCs('s', 5, name='Greens')[-2]
Purple = vizLib.getBCs('s', 5, name='Purples')[-2]

# %%
slopesDMSO = getSlopes(allListDMSO)
slopesCAM = getSlopes(allListCAM)
slopesLAM = getSlopes(allListLAM)
slopesERM = getSlopes(allListERM)

# %%
D = slopesDMSO
C = slopesCAM
L = slopesLAM
E = slopesERM
f = pylab.figure(figsize=(22,6))
a = f.add_subplot(111)
a.bar([i-0.4 for i in range(len(qMS.sort_nicely(D.keys())))], [D[i] for i in qMS.sort_nicely(D.keys())], align='edge', width=0.2, color=Blue, label='DMSO')
a.bar([i-0.2 for i in range(len(qMS.sort_nicely(C.keys())))], [C[i] for i in qMS.sort_nicely(C.keys())], align='edge', width=0.2, color=Red, label='CAM')
a.bar([i for i in range(len(qMS.sort_nicely(L.keys())))], [L[i] for i in qMS.sort_nicely(L.keys())], align='edge', width=0.2, color=Green, label='LAM')
a.bar([i + 0.2 for i in range(len(qMS.sort_nicely(E.keys())))], [E[i] for i in qMS.sort_nicely(E.keys())], align='edge', width=0.2, color=Purple, label='ERM')
pylab.legend()


a.set_xticks(range(54))
a.set_xlim(32,54)
a.set_ylim(0,0.0012)
a.set_yticks([0, 0.0004, 0.0008, 0.0012])
a.set_xticklabels(qMS.sort_nicely(D.keys()), size='medium', rotation='90')
a.set_ylabel('fit slope [using final 3 points]')
a.set_title('synthesis rate')
vizLib.cleanAxis(a,ticksOnly=True)
#pylab.savefig(savePath+'barGraphSynthesisRateSmall.png')
#pylab.savefig(savePath+'barGraphSynthesisRateSmall.pdf')

# %%
f = pylab.figure(figsize=(10,10))
a = f.add_subplot(111)
mew=1.25
ms=16

dX = numpy.linspace(0.25,0.75,54)
dY = [D[i] for i in qMS.sort_nicely(D.keys())]
a.plot(dX, [i*1e3 for i in dY], 'o', markersize=ms, color='none', markeredgecolor=Blue, markeredgewidth=mew, label='DMSO')

cX = dX + 1
cY = [C[i] for i in qMS.sort_nicely(C.keys())]
a.plot(cX, [i*1e3 for i in cY], 'o', markersize=ms, color='none', markeredgecolor=Red, markeredgewidth=mew, label='CAM')

lX = cX + 1
lY = [L[i] for i in qMS.sort_nicely(L.keys())]
a.plot(lX, [i*1e3 for i in lY], 'o', markersize=ms, color='none', markeredgecolor=Green, markeredgewidth=mew, label='LAM')

eX = lX + 1
eY = [E[i] for i in qMS.sort_nicely(E.keys())]
a.plot(eX, [i*1e3 for i in eY], 'o', markersize=ms, color='none', markeredgecolor=Purple, markeredgewidth=mew, label='ERM')

varArray = [qMS.to_precision(numpy.nanvar(i),2) for i in [dY, cY, lY, eY]]
numpy.set_printoptions(precision=2)
a.set_xlim(0,4)
a.set_ylim(2.5e-1, 1.2)
yt = [2.5e-5, .4e-3, .8e-3, 1.2e-3]
a.set_yticks([i*1e3 for i in yt])
a.set_xticks([0.5, 1.5, 2.5, 3.5])
a.set_ylabel('synthesis rate (e-3)', rotation='90')
a.set_xlabel('variance')
a.set_xticklabels(varArray, size='medium', rotation='0')
vizLib.cleanAxis(a,ticksOnly=True)
pylab.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=4, mode="expand", borderaxespad=0.)
pylab.savefig(savePath+'variance.png')
pylab.savefig(savePath+'variance.pdf')

# %%
num = ['AMP_L', 'AMP_U']
den = ['AMP_S']

msdDMSOPL = qMS.multiStatsDict(DMSO, num, den, normalization=1.0, offset=0.0, normProtein=None)
msdCAMPL = qMS.multiStatsDict(CAM, num, den, normalization=1.0, offset=0.0, normProtein=None)
msdLAMPL = qMS.multiStatsDict(LAM, num, den, normalization=1.0, offset=0.0, normProtein=None)
msdERMPL = qMS.multiStatsDict(ERM, num, den, normalization=1.0, offset=0.0, normProtein=None)

allListDMSOPL = qMS.calculateMedian(msdDMSO, DMSO, allSubunit)
allListCAMPL = qMS.calculateMedian(msdCAM, CAM, allSubunit)
allListLAMPL = qMS.calculateMedian(msdLAM, LAM, allSubunit)
allListERMPL = qMS.calculateMedian(msdERM, ERM, allSubunit)

dX = [allListDMSOPL[i][-1] for i in qMS.sort_nicely(allListDMSOPL.keys())]
cX = [allListCAMPL[i][-1] for i in qMS.sort_nicely(allListCAMPL.keys())]
lX = [allListLAMPL[i][-1] for i in qMS.sort_nicely(allListLAMPL.keys())]
eX = [allListERMPL[i][-1] for i in qMS.sort_nicely(allListERMPL.keys())]

# %%
f = pylab.figure(figsize=(10,10))
a = f.add_subplot(111)
mew=1.25
ms=16

a.plot(dX, dY, 'o', markersize=ms, color='none', markeredgecolor=Blue, markeredgewidth=mew, label='DMSO')

a.plot(cX, cY, 'o', markersize=ms, color='none', markeredgecolor=Red, markeredgewidth=mew, label='CAM')

a.plot(lX, lY, 'o', markersize=ms, color='none', markeredgecolor=Green, markeredgewidth=mew, label='LAM')

a.plot(eX, eY, 'o', markersize=ms, color='none', markeredgecolor=Purple, markeredgewidth=mew, label='ERM')

numpy.set_printoptions(precision=2)
a.set_ylabel('synthesis rate', rotation='90')
a.set_xlabel('protein level [16 hr]')
a.set_xlim(0,1)
a.set_ylim(0,0.0012)
vizLib.cleanAxis(a,ticksOnly=True)
pylab.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=4, mode="expand", borderaxespad=0.)
cFit = numpy.polyfit(cX[0:26], cY[0:26], 1)
fcX = numpy.linspace(0,1,100)
fcY = fcX*cFit[0] + cFit[1]
a.plot(fcX, fcY, '-', color=Red)
pylab.savefig(savePath+'synthVsLevel.png')
pylab.savefig(savePath+'synthVsLevel.pdf')
