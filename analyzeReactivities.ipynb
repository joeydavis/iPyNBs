# %%
import pylab
import numpy
import scipy
import pandas
import HTSeq
import itertools
import qMS

# %%
reac = '/home/jhdavis/data/2014/2014_06_07-ShapeSeqAnalysis/reactivities.out'

# %%
reac = pandas.read_csv(reac, sep='\t')

# %%
f = pylab.figure(figsize=(20,10))
a = f.add_subplot(111)
a.bar([int(i) for i in reac['five_prime_offset'].values[1:]], [float(i) for i in reac['theta'].values[1:]], color='red', edgecolor='none')

low = 2275
high = 2500
interval = 25

a.set_xlim(low, high)

a.set_xticks(numpy.linspace(low, high, (high-low+1)/(interval)+1))

a.set_ylim(0, 0.03)
pylab.tight_layout()
