# %%
import qMS
import pylab
import glob
import pandas
import numpy
import vizLib
import matplotlib.pyplot as plt
import qMSDefs

# %%
path = '/home/jhdavis/data/2014/2014_04_25-BrittonPLOSESITOF/isos/subunitSamples/'
num = ['AMP_U']
den = ['AMP_S']
files = glob.glob(path+'*_res_filt*.csv')
files = qMS.sort_nicely(files)
names = ['spkAlone', '1043_45S:RbgAF6A', '1051_44SRbgAF6A,L6R70P', '1055_44SRbgAF6A,L6R3C', '1057_44SRbgAF6A,L6H66L', '1068_44SRbgAF6A,L6G6C', '1043_70S', '1051_70S', '1055_70S', '1057_70S', '1068_70S']
#files

# %%
vizLib.setRcs(scale=16, legendScale=12, axisLineWidth=1)
colors = vizLib.getBCs('q',6)
filePath='/home/jhdavis/Dropbox/WilliamsonLab/Notebooks/ByDate/07/2014_05_06-BrittonPLOSSubunits/'
savePlots = True
fcounter=0

# %%
f = pylab.figure()
subunit = qMSDefs.subtilisLargeSubunit
#subunit.remove('BSubL09')
yMax = 5.0
figSize = [22,8]
median = False
normProtein = None
markerSize=8
highlightMed=True
noFill = False
hms=1.5
alpha=0.25
legend=True
title='raw spectra'
legendCols=6
loc='upper center'
ncol=6

larray = []
for i in range(0,6):
    l = pylab.Line2D(range(1),range(1),color=colors[i],marker='o',markersize=markerSize*hms, markerfacecolor=colors[i],alpha=1.0)
    larray.append(l)

a = vizLib.makePlotWithFileList(files[:6], num, den, subunits=subunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=names[:6], figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N', multialignment = 'center')

a.legend(larray,[names[i] for i in range(0,6)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'subunitsRawLarge_subs.png', bbox_inches='tight', dpi=300)
    fcounter+=1

f = pylab.figure()
subunit = qMSDefs.subtilisSmallSubunit
yMax = 3.0

a = vizLib.makePlotWithFileList(files[:6], num, den, subunits=subunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=names[:6], figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N', multialignment = 'center')

a.legend(larray,[names[i] for i in range(0,6)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'subunitsRawSmall_subs.png', bbox_inches='tight', dpi=300)
    fcounter+=1
# Out:
# /usr/lib/python2.7/dist-packages/numpy/core/_methods.py:55: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
f = pylab.figure()
subunit = qMSDefs.subtilisLargeSubunit
#subunit.remove('BSubL09')
yMax = 8.0
figSize = [22,8]
median = False
normProtein = None
markerSize=8
highlightMed=True
noFill = False
hms=1.5
alpha=0.25
legend=True
title='raw spectra'
legendCols=6

larray = []
for i in range(0,6):
    l = pylab.Line2D(range(1),range(1),color=colors[i],marker='o',markersize=markerSize*hms, markerfacecolor=colors[i],alpha=1.0)
    larray.append(l)


files70 = [files[0]] + files[6:]
names70 = [names[0]] + names[6:]


a = vizLib.makePlotWithFileList(files70, num, den, subunits=subunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=names70, figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N', multialignment = 'center')
a.legend(larray,[names70[i] for i in range(0,6)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'subunitsRawLarge_70S.png', bbox_inches='tight', dpi=300)
    fcounter+=1

f = pylab.figure()
subunit = qMSDefs.subtilisSmallSubunit
yMax = 3.0

a = vizLib.makePlotWithFileList(files70, num, den, subunits=subunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=names70, figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N', multialignment = 'center')

a.legend(larray,[names70[i] for i in range(0,6)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'subunitsRawSmall_70S.png', bbox_inches='tight', dpi=300)
    fcounter+=1

# %%
dictOfDF = qMS.correctListOfFiles(files[0], files[1:], extension='_corrPLOS0', savePath='/home/jhdavis/data/2014/2014_04_25-BrittonPLOSESITOF/isos/subunitSamples/corr')

# %%
path = '/home/jhdavis/data/2014/2014_04_25-BrittonPLOSESITOF/isos/subunitSamples/corr/'
num = ['AMP_U']
den = ['AMP_S']
corFiles = glob.glob(path+'*_res_filt*.csv_*')
corFiles = qMS.sort_nicely(corFiles)
corNames = names[1:]
colors = vizLib.getBCs('q',9)
colors.append('grey')
corFiles
# Out:
# ['/home/jhdavis/data/2014/2014_04_25-BrittonPLOSESITOF/isos/subunitSamples/corr/plos1_iso_res_filtAuto.csv_corrPLOS0',
#  '/home/jhdavis/data/2014/2014_04_25-BrittonPLOSESITOF/isos/subunitSamples/corr/plos2_iso_res_filtAuto.csv_corrPLOS0',
#  '/home/jhdavis/data/2014/2014_04_25-BrittonPLOSESITOF/isos/subunitSamples/corr/plos3_iso_res_filtAuto.csv_corrPLOS0',
#  '/home/jhdavis/data/2014/2014_04_25-BrittonPLOSESITOF/isos/subunitSamples/corr/plos4_iso_res_filtAuto.csv_corrPLOS0',
#  '/home/jhdavis/data/2014/2014_04_25-BrittonPLOSESITOF/isos/subunitSamples/corr/plos5_iso_res_filtAuto.csv_corrPLOS0',
#  '/home/jhdavis/data/2014/2014_04_25-BrittonPLOSESITOF/isos/subunitSamples/corr/plos6_iso_res_filtAuto.csv_corrPLOS0',
#  '/home/jhdavis/data/2014/2014_04_25-BrittonPLOSESITOF/isos/subunitSamples/corr/plos7_iso_res_filtAuto.csv_corrPLOS0',
#  '/home/jhdavis/data/2014/2014_04_25-BrittonPLOSESITOF/isos/subunitSamples/corr/plos8_iso_res_filtAuto.csv_corrPLOS0',
#  '/home/jhdavis/data/2014/2014_04_25-BrittonPLOSESITOF/isos/subunitSamples/corr/plos9_iso_res_filtAuto.csv_corrPLOS0',
#  '/home/jhdavis/data/2014/2014_04_25-BrittonPLOSESITOF/isos/subunitSamples/corr/plos10_iso_res_filtAuto.csv_corrPLOS0']

# %%
f = pylab.figure()
subunit = qMSDefs.subtilisLargeSubunit
#subunit.remove('BSubL09')
yMax = 2.5
figSize = [22,8]
median = False
normProtein = 'BSubL20'
markerSize=8
highlightMed=True
noFill = False
hms=1.5
alpha=0.25
legend=True
title='corected spectra'
legendCols=6
colors=colors[1:]


larray = []
for i in range(0,5):
    l = pylab.Line2D(range(1),range(1),color=colors[i],marker='o',markersize=markerSize*hms, markerfacecolor=colors[i],alpha=1.0)
    larray.append(l)


a = vizLib.makePlotWithFileList(corFiles[:5], num, den, subunits=subunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=corNames[:5], figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N cor [norm L20]', multialignment = 'center')
a.legend(larray,[corNames[i] for i in range(0,5)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'subunitsCorrLarge_subs.png', bbox_inches='tight', dpi=300)
    fcounter+=1

f = pylab.figure()
subunit = qMSDefs.subtilisSmallSubunit
yMax = 2

a = vizLib.makePlotWithFileList(corFiles[:5], num, den, subunits=subunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=corNames[:5], figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N cor [norm L20]', multialignment = 'center')

a.legend(larray,[corNames[i] for i in range(0,5)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'subunitsCorrSmall_subs.png', bbox_inches='tight', dpi=300)
    fcounter+=1

# %%
f = pylab.figure()
subunit = qMSDefs.subtilisLargeSubunit
#subunit.remove('BSubL09')
yMax = 2.5
figSize = [22,8]
median = False
normProtein = 'BSubL20'
markerSize=8
highlightMed=True
noFill = False
hms=1.5
alpha=0.25
legend=True
title='corected spectra'
legendCols=6

corNames70S = corNames[5:]
larray = []
for i in range(0,5):
    l = pylab.Line2D(range(1),range(1),color=colors[i],marker='o',markersize=markerSize*hms, markerfacecolor=colors[i],alpha=1.0)
    larray.append(l)


a = vizLib.makePlotWithFileList(corFiles[5:], num, den, subunits=subunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=corNames[5:], figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N cor [norm L20]', multialignment = 'center')
a.legend(larray,[corNames70S[i] for i in range(0,5)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'subunitsCorrLarge_70S.png', bbox_inches='tight', dpi=300)
    fcounter+=1

f = pylab.figure()
subunit = qMSDefs.subtilisSmallSubunit
yMax = 2

a = vizLib.makePlotWithFileList(corFiles[5:], num, den, subunits=subunit, yMax=yMax, colors=colors, noFill = noFill,
                                names=corNames[5:], figSize=figSize, median=median, normProtein=normProtein, 
                                markerSize=markerSize, highlightMed=highlightMed, alpha=alpha, hms=hms, 
                                legend=legend, title=title, legendCols=legendCols)
a.set_xlabel('protein name')
a.set_ylabel('14N / 15N cor [norm L20]', multialignment = 'center')

a.legend(larray,[corNames70S[i] for i in range(0,5)],numpoints=1,loc=loc, ncol=ncol, fancybox=False, shadow=False)
vizLib.cleanAxis(a, ticksOnly=True)

if savePlots:
    pylab.savefig(filePath + str(fcounter) + 'subunitsCorrSmall_70S.png', bbox_inches='tight', dpi=300)
    fcounter+=1
