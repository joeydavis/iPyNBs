# %%
import pylab
import numpy
import qMS
import glob
import qMSDefs

# %%
pathESI = '/home/jhdavis/McMasterMSUDataSets/L16LysisExpt/2013_07_27-MSUABCDESITOF/'
filesESI = qMS.sort_nicely([i.split('/')[-1] for i in glob.glob(pathESI+'*.csv')])

pathTTOF = '/home/jhdavis/McMasterMSUDataSets/L16LysisExpt/2013_08_02-msuABCDTTOF/'
filesTTOF = qMS.sort_nicely([i.split('/')[-1] for i in glob.glob(pathTTOF+'*.csv')])

esiNames = qMSDefs.subtilisLargeSubunit
ttofNames = qMSDefs.subtilisTTOFLargeSubunit

# %%
for i in range(len(filesTTOF)):
    fullPath = pathTTOF+filesTTOF[i]
    qMS.convertNames(fullPath, ttofNames, esiNames)
# Out:
# ###########################OLD#########################
# 0     RL16
# 1     RL10
# 2     RL15
# 3     RL16
# 4      RL2
# 5      RL5
# 6     RL35
# 7     RL13
# 8     RL14
# 9     RL22
# 10    RL18
# 11    RL13
# 12    RL21
# 13     RL7
# 14     RL3
# ...
# 167      RL5
# 168      RL5
# 169      RL3
# 170     RL11
# 171      RL5
# 172     RL16
# 173     RL10
# 174    RL31B
# 175      RL2
# 176      RL5
# 177     RL30
# 178     RL10
# 179     RL18
# 180     RL17
# 181      RL5
# Name: protein, Length: 182
# ###########################NEW#########################
# 0     BSubL16
# 1     BSubL10
# 2     BSubL15
# 3     BSubL16
# 4     BSubL02
# 5     BSubL05
# 6     BSubL35
# 7     BSubL13
# 8     BSubL14
# 9     BSubL22
# 10    BSubL18
# 11    BSubL13
# 12    BSubL21
# 13    BSubL12
# 14    BSubL03
# ...
# 167    BSubL05
# 168    BSubL05
# 169    BSubL03
# 170    BSubL11
# 171    BSubL05
# 172    BSubL16
# 173    BSubL10
# 174      RL31B
# 175    BSubL02
# 176    BSubL05
# ...

# %%
newCol = dataFrame['protein']

# %%
newCol.columns=['protein']

# %%
newCol.replace(TTOFtoESI)
# Out:
# 0     BSubL16
# 1     BSubL10
# 2     BSubL15
# 3     BSubL16
# 4     BSubL02
# 5     BSubL05
# 6     BSubL35
# 7     BSubL13
# 8     BSubL14
# 9     BSubL22
# 10    BSubL18
# 11    BSubL13
# 12    BSubL21
# 13    BSubL12
# 14    BSubL03
# ...
# 167    BSubL05
# 168    BSubL05
# 169    BSubL03
# 170    BSubL11
# 171    BSubL05
# 172    BSubL16
# 173    BSubL10
# 174      RL31B
# 175    BSubL02
# 176    BSubL05
# 177    BSubL30
# 178    BSubL10
# 179    BSubL18
# 180    BSubL17
# 181    BSubL05
# Name: protein, Length: 182

# %%
dataFrame.update(newCol)

# %%
dataFrame['protein']
# Out:
# 0     BSubL16
# 1     BSubL10
# 2     BSubL15
# 3     BSubL16
# 4     BSubL02
# 5     BSubL05
# 6     BSubL35
# 7     BSubL13
# 8     BSubL14
# 9     BSubL22
# 10    BSubL18
# 11    BSubL13
# 12    BSubL21
# 13    BSubL12
# 14    BSubL03
# ...
# 167    BSubL05
# 168    BSubL05
# 169    BSubL03
# 170    BSubL11
# 171    BSubL05
# 172    BSubL16
# 173    BSubL10
# 174      RL31B
# 175    BSubL02
# 176    BSubL05
# 177    BSubL30
# 178    BSubL10
# 179    BSubL18
# 180    BSubL17
# 181    BSubL05
# Name: protein, Length: 182
